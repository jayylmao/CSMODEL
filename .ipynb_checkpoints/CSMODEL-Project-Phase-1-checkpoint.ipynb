# %% [markdown]
# # Global Ecological Footprint 2023
# **Group 6**
# - Jay Michael Carlos
# - Seth Jovellana
# - Janica Megan Reyes
# - Abigail Vicencio
#
# ---
# Dataset uploaded by user JAINA to kaggle at https://www.kaggle.com/datasets/jainaru/global-ecological-footprint-2023.
#
# Original dataset:
# York University Ecological Footprint Initiative & Global Footprint Network. Public Data Package of the National Footprint and Biocapacity Accounts, 2023 edition. Produced for the Footprint Data Foundation and distributed by Global Footprint Network. Available online at: https://data.footprintnetwork.org.

# %% [markdown]
# # Dataset Description
# This dataset contains measures of various ecological assets that a country needs to produce the natural resources that its population consumes. Six categories are tracked:
# - Crop land
# - Grazing land
# - Fishing grounds
# - Built-up (urban) land
# - Forest area
# - Carbon demand on land
# In addition, it also contains other economic factors such as per capita GDP and income group.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Need a specific encode setting to decode without eror.
eco_df = pd.read_csv('global-ecological-footprint-2023.csv', encoding = 'unicode_escape')

# %%
eco_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Country                                   182 non-null    object
#  1   Region                                    182 non-null    object
#  2   SDGi                                      159 non-null    object
#  3   Life Exectancy                            176 non-null    object
#  4   HDI                                       173 non-null    object
#  5   Per Capita GDP                            165 non-null    object
#  6   Income Group                              178 non-null    object
#  7   Population (millions)                     182 non-null    object
#  8   Cropland Footprint                        152 non-null    float64
#  9   Grazing Footprint                         152 non-null    float64
#  10  Forest Product Footprint                  152 non-null    float64
#  11  Carbon Footprint                          152 non-null    float64
#  12  Fish Footprint                            152 non-null    float64
#  13  Built up land                             152 non-null    float64
#  14  Total Ecological Footprint (Consumption)  181 non-null    float64
#  15  Cropland                                  152 non-null    float64
#  16  Grazing land                              152 non-null    float64
#  17  Forest land                               152 non-null    float64
#  18  Fishing ground                            152 non-null    float64
#  19  Built up land.1                           152 non-null    float64
#  20  Total biocapacity                         181 non-null    float64
#  21  Ecological (Deficit) or Reserve           181 non-null    float64
#  22  Number of Earths required                 181 non-null    float64
#  23  Number of Countries required              181 non-null    float64
# dtypes: float64(16), object(8)
# memory usage: 34.3+ KB

# %% [markdown]
# ## Collection process and methodology

# %% [markdown]
# ## Structure
# Each column of the dataset represents a country's measure, such as the average life expectancy or its population. Each row is an observation of the variables per country.

# %%
eco_df.head()
# Out:
#                Country                     Region  SDGi Life Exectancy   HDI  \
# 0          Afghanistan   Middle East/Central Asia  52.5             62  0.48
# 1              Albania               Other Europe  71.6             76   0.8
# 2              Algeria                     Africa  71.5             76  0.75
# 3               Angola                     Africa  50.9             62  0.59
# 4  Antigua and Barbuda  Central America/Caribbean   NaN             78  0.79
#
#   Per Capita GDP Income Group Population (millions)  Cropland Footprint  \
# 0            NaN           LI                  40.8                 0.4
# 1       $14,889            UM                   2.9                 0.8
# 2       $11,137            UM                  45.4                 0.7
# 3        $6,304            LM                    35                 0.2
# 4       $18,749            HI                   0.1                 NaN
#
#    Grazing Footprint  ...  Total Ecological Footprint (Consumption)  Cropland  \
# 0                0.1  ...                                       0.8       0.3
# 1                0.2  ...                                       2.1       0.6
# 2                0.2  ...                                       2.2       0.4
# 3                0.1  ...                                       0.9       0.2
# 4                NaN  ...                                       2.9       NaN
#
#    Grazing land  Forest land  Fishing ground  Built up land.1  \
# 0           0.1     0.012981        0.000565         0.028232
# 1           0.2     0.223326        0.081392         0.073006
# 2           0.2     0.023912        0.007179         0.037775
# 3           0.8     0.416888        0.153499         0.061360
# 4           NaN          NaN             NaN              NaN
#
#    Total biocapacity   Ecological (Deficit) or Reserve  \
# 0            0.513827                        -0.287638
# 1            1.176752                        -0.894486
# 2            0.663375                        -1.559593
# 3            1.588191                         0.730346
# 4            0.917277                        -2.019458
#
#    Number of Earths required  Number of Countries required
# 0                   0.530696                      1.559795
# 1                   1.371485                      1.760131
# 2                   1.471955                      3.350998
# 3                   0.568029                      0.540140
# 4                   1.944580                      3.201578
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Column definitions
# 0. Country: The name of the country being observed.
# 1. Region: The region of the world that the country is in, like Asia-Pacific, North America, Africa, etc.
# 2. SDGi: The SDG Index is a measure of progress of all UN member states on the Sustainable Development Goals.
# 3. Life Exectancy *\(sic\)*: The number of years a person can expect to live. (Esteban Ortiz-Ospina, 2017)
# 4. HDI: The United Nations' Human Development Index is an approximate measure of economic and social development based on three dimensions: health, education, and standard of living. Health is measured by life expectancy at birth, education is measured by mean of years of schooling, and standard of living is measured by gross national income per capita. Each country is then given a value from 0 to 1. An HDI of > 0.7 is considered "high human development". (United Nations Development Programme, 2023)
# 5. Per Capita GDP: Measured as the GDP (gross domestic product) of a nation divided by its population. It is used to measure the prosperity of a nation. (Investopedia, 2024)
# 6. Income Group: The World Bank Group (2023) assigns countries around the world to one of four income groups: low, lower-middle, upper-middle, and high. This is represented in the dataset as LI (low), LM (lower-middle), UM (upper-middle), and HI (high).
# 7. Population (millions): All people inhabiting a country, shown in millions in the dataset. (Merriam-Webster, 2024)
# 8. Cropland Footprint: The ecological footprint (defined below) used to produce food and fiber for human consumption and feed for livestock and other uses. All footprint is measured in global hectares per person. (York University Ecological Footprint Initiative & Global Footprint Network, 2023)
# 9. Grazing Footprint:
# 10. Forest Product Footprint:
# 11. Carbon Footprint:
# 12. Fish Footprint:
# 13. Built up land:
# 14. Total Ecological Footprint (Consumption): A measure of productive land and water area that a population requires to produce all the resources it consumes and to absorb the waste that it generates. This is measured in **global hectares per person**, which is defined as a biologically productive hectare with world average productivity. (York University Ecological Footprint Initiative & Global Footprint Network, 2023)
# 15. Cropland: The biocapacity (defined below) of land used to produce food and fiber for human consumption and feed. (York University Ecological Footprint Initiative & Global Footprint Network, 2023)
# 16. Grazing land:
# 17. Forest land:
# 18. Fishing ground:
# 19. Built up land.1:
# 20. Total biocapacity: The capacity of biologically productive areas to provide for human demand (footprints). It is also measured in global hectares per person. (York University Ecological Footprint Initiative & Global Footprint Network, 2023)
# 21. Ecological (Deficit) or Reserve: This variable measures a country's ecological footprint relative to its biocapacity. If the country's ecological footprint exceeds its biocapacity, there is an ecological deficit. If the country's biocapacity exceeds its ecological footprint, there is an ecological reserve. Like biocapacity and ecological footprint, this is measured in global hectares per person. (York University Ecological Footprint Initiative & Global Footprint Network, 2023)
# 22. Number of Earths required: The number of planet Earths required for everyone in the world to sustain the resources needed to live the average lifestyle of a person in the observed country. (York University Ecological Footprint Initiative & Global Footprint Network, 2023)
# 23. Number of Countries required: Represents how many times the observed country's total biocapacity is needed to provide for its consumption footprint. (York University Ecological Footprint Initiative & Global Footprint Network, 2023)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# One of the variables to be used is Per Capita GDP. It is represented with a dollar sign and is formatted with commas for readability, however, to properly visualize it, it must be converted to a standard float value without the dollar sign and commas. Additionally, the 17 missing values must be dropped from the table.

# %%
nan_per_capita_gdp = eco_df['Per Capita GDP'].isna().sum()
print('There are', nan_per_capita_gdp, 'countries with no recorded per capita GDP.')
# Out:
# There are 17 countries with no recorded per capita GDP.

# %%
no_nan_pcgdp_eco_df = eco_df[eco_df['Per Capita GDP'].notna()].astype(str)
no_nan_pcgdp_eco_df = eco_df.replace(' ', np.nan)
no_nan_pcgdp_eco_df.head(50)
# Out:
#                           Country                     Region  SDGi  \
# 0                     Afghanistan   Middle East/Central Asia  52.5
# 1                         Albania               Other Europe  71.6
# 2                         Algeria                     Africa  71.5
# 3                          Angola                     Africa  50.9
# 4             Antigua and Barbuda  Central America/Caribbean   NaN
# 5                       Argentina              South America  72.8
# 6                         Armenia   Middle East/Central Asia  71.1
# 7                       Australia               Asia-Pacific  75.6
# 8                         Austria                      EU-27  82.3
# 9                      Azerbaijan   Middle East/Central Asia  73.5
# 10                        Bahrain   Middle East/Central Asia  64.3
# 11                     Bangladesh               Asia-Pacific  64.2
# 12                       Barbados  Central America/Caribbean  70.3
# 13                        Belarus               Other Europe    76
# 14                        Belgium                      EU-27  79.7
# 15                         Belize  Central America/Caribbean  65.7
# 16                          Benin                     Africa  51.2
# 17                        Bermuda              North America   NaN
# 18                         Bhutan               Asia-Pacific  70.5
# 19                        Bolivia              South America    68
# 20         Bosnia and Herzegovina               Other Europe  71.7
# 21                       Botswana                     Africa  61.4
# 22                         Brazil              South America  72.8
# 23              Brunei Darussalam               Asia-Pacific  67.1
# 24                       Bulgaria                      EU-27  74.3
# 25                   Burkina Faso                     Africa  54.5
# 26                        Burundi                     Africa  54.1
# 27                     Cabo Verde                     Africa   NaN
# 28                       Cambodia               Asia-Pacific  63.8
# 29                       Cameroon                     Africa  55.5
# 30                         Canada              North America  77.7
# 31       Central African Republic                     Africa  39.3
# 32                           Chad                     Africa  41.3
# 33                          Chile              South America  77.8
# 34                          China               Asia-Pacific  72.4
# 35                       Colombia              South America  70.1
# 36                        Comoros                     Africa   NaN
# 37                          Congo                     Africa  52.3
# 38  Congo, Democratic Republic of                     Africa    50
# 39                     Costa Rica  Central America/Caribbean  73.8
# 40                  Côte d'Ivoire                     Africa
# 41                        Croatia               Other Europe  78.8
# 42                           Cuba  Central America/Caribbean  74.7
# 43                         Cyprus                      EU-27  74.2
# 44                 Czech Republic                      EU-27  80.5
# 45                        Denmark                      EU-27  85.6
# 46                       Djibouti                     Africa  50.3
# 47                       Dominica  Central America/Caribbean   NaN
# 48             Dominican Republic  Central America/Caribbean  70.8
# 49                        Ecuador              South America  71.5
#
#    Life Exectancy   HDI Per Capita GDP Income Group Population (millions)  \
# 0              62  0.48            NaN           LI                  40.8
# 1              76   0.8       $14,889            UM                   2.9
# 2              76  0.75       $11,137            UM                  45.4
# 3              62  0.59        $6,304            LM                    35
# 4              78  0.79       $18,749            HI                   0.1
# 5              75  0.84       $22,117            UM                    46
# 6              72  0.76       $13,548            LM                     3
# 7              83  0.95       $53,053            HI                  26.1
# 8              81  0.92       $55,460            HI                   9.1
# 9              69  0.75       $14,692            UM                  10.3
# 10             79  0.88       $49,184            HI                   1.8
# 11             72  0.66        $5,681            LI                 167.9
# 12             78  0.79       $14,910            HI                   0.3
# 13             72  0.81       $18,574            UM                   9.4
# 14             82  0.94       $52,749            HI                  11.7
# 15             70  0.68        $6,122            UM                   0.4
# 16             60  0.53        $3,543            LI                  12.8
# 17             79   NaN            NaN           HI                   0.1
# 18             72  0.67       $11,106            LM                   0.8
# 19             64  0.69        $8,442            LM                    12
# 20             75  0.78       $14,964            UM                   3.2
# 21             61  0.69       $16,519            UM                   2.4
# 22             73  0.75       $14,739            UM                 215.4
# 23             75  0.83       $64,198            HI                   0.4
# 24             72   0.8       $24,490            UM                   6.8
# 25             59  0.45        $2,281            LI                  22.1
# 26             62  0.43          $733            LI                  12.6
# 27             74  0.66        $6,629            LM                   0.6
# 28             70  0.59        $4,705            LI                  17.2
# 29             60  0.58        $3,767            LM                  27.9
# 30             83  0.94       $49,516            HI                  38.4
# 31             54   0.4          $944            LI                     5
# 32             53  0.39        $1,460            LI                  17.4
# 33             79  0.86       $24,433            UM                  19.3
# 34             78  0.77       $18,299            UM              1,480.60
# 35             73  0.75       $15,610            UM                  51.5
# 36             63  0.56        $2,874            LI                   0.9
# 37             64  0.57        $3,921            LM                   5.8
# 38             59  0.48        $1,127            LI                  95.2
# 39             77  0.81       $20,976            UM                   5.2
# 40                                               LM                  27.7
# 41             76  0.86       $31,007            HI                   4.1
# 42             74  0.76                          UM                  11.3
# 43             81   0.9       $41,492            HI                   1.2
# 44             77  0.89       $40,707            HI                  10.7
# 45             81  0.95       $59,333            HI                   5.8
# 46             62  0.51        $5,710            LM                     1
# 47             73  0.72       $12,412            UM                   0.1
# 48             73  0.77       $20,541            UM                  11.1
# 49             74  0.74       $10,847            UM                  18.1
#
#     Cropland Footprint  Grazing Footprint  ...  \
# 0                  0.4                0.1  ...
# 1                  0.8                0.2  ...
# 2                  0.7                0.2  ...
# 3                  0.2                0.1  ...
# 4                  NaN                NaN  ...
# 5                  0.9                0.5  ...
# 6                  0.7                0.2  ...
# 7                  0.1                0.5  ...
# 8                  1.0                0.3  ...
# 9                  0.8                0.2  ...
# 10                 0.5                0.4  ...
# 11                 0.2                0.0  ...
# 12                 0.6                0.3  ...
# 13                 1.5                0.1  ...
# 14                 1.4                0.4  ...
# 15                 0.2                0.3  ...
# 16                 0.4                0.0  ...
# 17                 NaN                NaN  ...
# 18                 0.6                0.3  ...
# 19                 0.3                1.6  ...
# 20                 1.1                0.4  ...
# 21                 0.3                0.3  ...
# 22                 0.5                0.6  ...
# 23                 0.4                0.2  ...
# 24                 0.8                0.2  ...
# 25                 0.3                0.1  ...
# 26                 0.3                0.1  ...
# 27                 NaN                NaN  ...
# 28                 NaN                NaN  ...
# 29                 0.5                0.1  ...
# 30                 1.3                0.3  ...
# 31                 0.4                0.4  ...
# 32                 0.3                0.8  ...
# 33                 0.6                0.5  ...
# 34                 0.5                0.1  ...
# 35                 0.6                0.7  ...
# 36                 NaN                NaN  ...
# 37                 0.3                0.1  ...
# 38                 0.2                0.0  ...
# 39                 0.4                0.1  ...
# 40                 0.3                0.1  ...
# 41                 0.8                0.2  ...
# 42                 0.8                0.1  ...
# 43                 NaN                NaN  ...
# 44                 1.0                0.3  ...
# 45                 1.9                0.4  ...
# 46                 1.6                0.1  ...
# 47                 NaN                NaN  ...
# 48                 0.5                0.1  ...
# 49                 NaN                NaN  ...
#
#     Total Ecological Footprint (Consumption)  Cropland  Grazing land  \
# 0                                        0.8       0.3           0.1
# 1                                        2.1       0.6           0.2
# 2                                        2.2       0.4           0.2
# 3                                        0.9       0.2           0.8
# 4                                        2.9       NaN           NaN
# 5                                        3.2       1.8           1.2
# 6                                        2.3       0.4           0.3
# 7                                        5.8       1.8           4.5
# 8                                        5.6       0.6           0.1
# 9                                        2.4       0.6           0.2
# 10                                       8.2       0.0           0.0
# 11                                       0.7       0.1           0.0
# 12                                       3.3       0.1           0.0
# 13                                       4.6       1.7           0.2
# 14                                       6.7       0.4           0.1
# 15                                       7.5       0.5           0.2
# 16                                       1.1       0.4           0.0
# 17                                       NaN       NaN           NaN
# 18                                       4.7       0.3           0.3
# 19                                       2.8       0.6           1.9
# 20                                       4.3       0.8           0.3
# 21                                       2.2       0.1           1.9
# 22                                       2.6       0.8           0.8
# 23                                       7.9       0.0           0.0
# 24                                       3.6       1.5           0.2
# 25                                       0.9       0.3           0.1
# 26                                       0.6       0.2           0.1
# 27                                       1.2       NaN           NaN
# 28                                       1.3       NaN           NaN
# 29                                       1.0       0.5           0.1
# 30                                       7.4       2.7           0.3
# 31                                       1.1       0.4           0.5
# 32                                       1.4       0.3           0.8
# 33                                       3.8       0.3           0.4
# 34                                       3.6       0.3           0.1
# 35                                       2.0       0.5           1.1
# 36                                       2.0       NaN           NaN
# 37                                       1.1       0.2           2.3
# 38                                       0.7       0.2           0.2
# 39                                       2.6       0.3           0.3
# 40                                       0.9       0.5           0.4
# 41                                       3.7       0.7           0.2
# 42                                       1.9       0.5           0.1
# 43                                       3.2       NaN           NaN
# 44                                       5.1       1.1           0.1
# 45                                       7.3       1.8           0.0
# 46                                       2.5       0.0           0.2
# 47                                       2.7       NaN           NaN
# 48                                       1.8       0.3           0.1
# 49                                       1.7       NaN           NaN
#
#     Forest land  Fishing ground  Built up land.1  Total biocapacity   \
# 0      0.012981        0.000565         0.028232            0.513827
# 1      0.223326        0.081392         0.073006            1.176752
# 2      0.023912        0.007179         0.037775            0.663375
# 3      0.416888        0.153499         0.061360            1.588191
# 4           NaN             NaN              NaN            0.917277
# 5      0.591673        1.527615         0.083517            5.231663
# 6      0.098200        0.016853         0.052182            0.846625
# 7      1.861992        2.827503         0.024587           11.021401
# 8      1.952260        0.005609         0.194413            2.893775
# 9      0.103819        0.014092         0.045343            0.936955
# 10     0.000851        0.418959         0.128778            0.555726
# 11     0.004830        0.048881         0.065360            0.247818
# 12     0.018580        0.044342         0.122921            0.259911
# 13     1.671707        0.017935         0.054224            3.702523
# 14     0.282651        0.042004         0.412600            1.161287
# 15     1.755451        0.895604         0.002146            3.303245
# 16     0.175878        0.017101         0.039340            0.633464
# 17          NaN             NaN              NaN                 NaN
# 18     4.036194        0.011789         0.180000            4.872816
# 19    10.605888        0.046120         0.070952           13.235907
# 20     1.058868        0.000238         0.038085            2.173852
# 21     0.645553        0.210411         0.033460            2.902420
# 22     6.128738        0.158959         0.236773            8.177126
# 23     1.402184        1.156232         0.038099            2.617611
# 24     1.119766        0.136830         0.110499            3.084292
# 25     0.203775        0.001009         0.022284            0.694622
# 26     0.007317        0.006154         0.049625            0.356307
# 27          NaN             NaN              NaN            0.437321
# 28          NaN             NaN              NaN            1.011947
# 29     0.726351        0.060929         0.050793            1.426699
# 30     8.024230        3.150398         0.040870           14.241061
# 31     5.526731        0.000000         0.023684            6.411714
# 32     0.238273        0.051628         0.023336            1.442214
# 33     2.038244        0.343150         0.118356            3.231436
# 34     0.223059        0.042215         0.123910            0.802130
# 35     1.895293        0.063673         0.066788            3.587635
# 36          NaN             NaN              NaN            0.332178
# 37     5.078504        0.259849         0.061983            7.831302
# 38     1.348660        0.031009         0.081315            1.846246
# 39     0.643532        0.111496         0.251434            1.615102
# 40     0.092553        0.029642         0.050965            1.106373
# 41     1.163262        0.360783         0.155073            2.571672
# 42     0.239531        0.168782         0.067479            1.115084
# 43          NaN             NaN              NaN            0.380453
# 44     1.242041        0.005852         0.122171            2.522006
# 45     0.394444        1.753242         0.216036            4.216546
# 46     0.001715        0.234447         0.214843            0.633920
# 47          NaN             NaN              NaN            1.004335
# 48     0.157583        0.022516         0.111284            0.681747
# 49          NaN             NaN              NaN            1.872751
#
#     Ecological (Deficit) or Reserve  Number of Earths required  \
# 0                         -0.287638                   0.530696
# 1                         -0.894486                   1.371485
# 2                         -1.559593                   1.471955
# 3                          0.730346                   0.568029
# 4                         -2.019458                   1.944580
# 5                          2.011045                   2.132556
# 6                         -1.479770                   1.540439
# 7                          5.244362                   3.825307
# 8                         -2.732866                   3.725721
# 9                         -1.420134                   1.560763
# 10                        -7.620475                   5.413931
# 11                        -0.422907                   0.444125
# 12                        -3.054225                   2.194479
# 13                        -0.875730                   3.031523
# 14                        -5.528362                   4.429599
# 15                        -4.227131                   4.986293
# 16                        -0.477126                   0.735385
# 17                              NaN                        NaN
# 18                         0.152248                   3.125758
# 19                        10.463372                   1.835854
# 20                        -2.091694                   2.824462
# 21                         0.680635                   1.471171
# 22                         5.625307                   1.689706
# 23                        -5.291012                   5.236752
# 24                        -0.497837                   2.371933
# 25                        -0.203164                   0.594476
# 26                        -0.237299                   0.393060
# 27                        -0.724858                   0.769545
# 28                        -0.327504                   0.886927
# 29                         0.382675                   0.691308
# 30                         6.820420                   4.913631
# 31                         5.294840                   0.739546
# 32                         0.067590                   0.910217
# 33                        -0.610397                   2.543898
# 34                        -2.816519                   2.396114
# 35                         1.610521                   1.309160
# 36                        -1.652632                   1.314256
# 37                         6.712954                   0.740522
# 38                         1.160857                   0.453836
# 39                        -0.983839                   1.720907
# 40                         0.221608                   0.585853
# 41                        -1.140193                   2.457838
# 42                        -0.801956                   1.269382
# 43                        -2.808880                   2.111840
# 44                        -2.561014                   3.365758
# 45                        -3.069923                   4.824788
# 46                        -1.823462                   1.627173
# 47                        -1.682666                   1.779217
# 48                        -1.121494                   1.194030
# 49                         0.194463                   1.111290
#
#     Number of Countries required
# 0                       1.559795
# 1                       1.760131
# 2                       3.350998
# 3                       0.540140
# 4                       3.201578
# 5                       0.615601
# 6                       2.747847
# 7                       0.524166
# 8                       1.944395
# 9                       2.515692
# 10                     14.712646
# 11                      2.706519
# 12                     12.751041
# 13                      1.236522
# 14                      5.760547
# 15                      2.279690
# 16                      1.753202
# 17                           NaN
# 18                      0.968756
# 19                      0.209471
# 20                      1.962206
# 21                      0.765494
# 22                      0.312068
# 23                      3.021313
# 24                      1.161410
# 25                      1.292481
# 26                      1.665997
# 27                      2.657499
# 28                      1.323638
# 29                      0.731776
# 30                      0.521074
# 31                      0.174193
# 32                      0.953135
# 33                      1.188893
# 34                      4.511299
# 35                      0.551091
# 36                      5.975144
# 37                      0.142805
# 38                      0.371234
# 39                      1.609150
# 40                      0.799698
# 41                      1.443366
# 42                      1.719189
# 43                      8.382981
# 44                      2.015467
# 45                      1.728066
# 46                      3.876486
# 47                      2.675403
# 48                      2.645029
# 49                      0.896162
#
# [50 rows x 24 columns]

# %%
cleaned_pcgdp = no_nan_pcgdp_eco_df['Per Capita GDP'].str.replace('$', '').str.replace(',', '')
cleaned_pcgdp.head()
# Out:
# 0       NaN
# 1    14889
# 2    11137
# 3     6304
# 4    18749
# Name: Per Capita GDP, dtype: object

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Research Questions

# %% [markdown]
# # References
# @JAINA. (2024). *Global Ecological Footprint 2023🌐\[latest report\]*. Kaggle. https://www.kaggle.com/datasets/jainaru/global-ecological-footprint-2023.
#
# Esteban Ortiz-Ospina. (2017). *"Life Expectancy" – What does this actually mean?*. Published online at OurWorldInData.org. https://ourworldindata.org/life-expectancy-how-is-it-calculated-and-how-should-it-be-interpreted.
#
# Investopedia. (2024). *GDP Per Capita: Definition, Uses, and Highest Per Country*. https://www.investopedia.com/terms/p/per-capita-gdp.asp.
#
# Merriam-Webster. (2024). *Population definition*. https://www.merriam-webster.com/dictionary/population
#
# UN Sustainable Development Solutions Network. (2022). *Sustainable Development Goals Index*. https://www.sdgindex.org/.
#
# United Nations Development Programme. (2023). *Human Development Report*. http://hdr.undp.org/en/data.
#
# International Monetary Fund. (2023). *World Economic Outlook*. https://www.imf.org/en/Publications/WEO
#
# Hamadeh, N., Van Rompaey, C, & Metreau, E. (2023). *World Bank Group country classifications by income level for FY24 (July 1, 2023- June 30, 2024)*. https://blogs.worldbank.org/en/opendata/new-world-bank-group-country-classifications-income-level-fy24
#
# York University Ecological Footprint Initiative & Global Footprint Network. *Public Data Package of the National Footprint and Biocapacity Accounts, 2023 edition*. Produced for the Footprint Data Foundation and distributed by Global Footprint Network. https://data.footprintnetwork.org.
